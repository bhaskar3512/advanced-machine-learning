# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaskar3512/advanced-machine-learning/blob/main/k_mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = pd.read_csv("/content/sample_data/california_housing_test.csv")

X = df[['longitude', 'latitude']]

kmeans = KMeans(n_clusters=3)
df['Cluster'] = kmeans.fit_predict(X)

plt.scatter(df['longitude'], df['latitude'], c=df['Cluster'])
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("K-Means Clustering (Scatter Plot)")
plt.show()
